# %%
words = [
    "doctor",
    "nurse",
    "engineer",
    "scientist",
    "programmer",
    "teacher",
    "receptionist",
    "homemaker",
    "lawyer",
    "manager",
    "janitor",
    "soldier",
    "cat",
    "pink",
    "leader",
    "boss",
    "authority",
    "recipe",
    "therapy",
    "success",
    "gun",
    "money",
]
